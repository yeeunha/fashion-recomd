# %%
import os
from PIL import Image
import cv2

# %%
path = "/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭/유니크/" # 스타일 입력
mall = os.listdir(path) # 쇼핑몰 리스트
for i in range(len(mall)):
  path2 = path + mall[i] + '/'
  file_list = os.listdir(path2)
  file_list_py = [file for file in file_list if file.endswith('.jpg')] # 한 쇼핑몰 폴더에 있는 이미지 파일 리스트

  for j in range(len(file_list_py)) :
    # 입력 이미지 로드
    image = Image.open(path2 + file_list_py[j])
    img_size = image.size #이미지의 크기 측정
    x = img_size[0] #넓이값
    y = img_size[1] #높이값

    if x != y:
      size = max(x, y)
      resized_img = Image.new(mode = 'RGB', size = (size, size), color = (255, 255, 255))
      offset = (round((abs(x - size)) / 2), round((abs(y - size)) / 2))
      resized_img.paste(image, offset)

      output_path = '/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭_정사각형/유니크/' + mall[i] + '/resized_' + file_list_py[j]
      resized_img.save(output_path,'png')

      print(f'{i}번째 몰인 {mall[i]}의 {j}번째 이미지가 성공적으로 저장되었습니다.')
# Out:
# 0번째 몰인 블랙업의 0번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 1번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 2번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 3번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 4번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 5번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 6번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 7번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 8번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 9번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 10번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 11번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 12번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 13번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 14번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 15번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 16번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 17번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 18번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 19번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 20번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 블랙업의 21번째 이미지가 성공적으로 저장되었습니다.
# ...

# %%
path = "/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭/로맨틱/" # 스타일 입력
mall = os.listdir(path) # 쇼핑몰 리스트
for i in range(len(mall)):
  path2 = path + mall[i] + '/'
  file_list = os.listdir(path2)
  file_list_py = [file for file in file_list if file.endswith('.jpg')] # 한 쇼핑몰 폴더에 있는 이미지 파일 리스트

  for j in range(len(file_list_py)) :
    # 입력 이미지 로드
    image = Image.open(path2 + file_list_py[j])
    img_size = image.size #이미지의 크기 측정
    x = img_size[0] #넓이값
    y = img_size[1] #높이값

    if x != y:
      size = max(x, y)
      resized_img = Image.new(mode = 'RGB', size = (size, size), color = (255, 255, 255))
      offset = (round((abs(x - size)) / 2), round((abs(y - size)) / 2))
      resized_img.paste(image, offset)

      output_path = '/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭_정사각형/로맨틱/' + mall[i] + '/resized_' + file_list_py[j]
      resized_img.save(output_path,'png')

      print(f'{i}번째 몰인 {mall[i]}의 {j}번째 이미지가 성공적으로 저장되었습니다.')
# Out:
# 0번째 몰인 큐니걸스의 0번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 1번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 2번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 3번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 4번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 5번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 6번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 7번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 8번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 9번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 10번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 11번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 12번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 13번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 14번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 15번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 16번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 17번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 18번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 19번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 20번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 큐니걸스의 21번째 이미지가 성공적으로 저장되었습니다.
# ...

# %%
path = "/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭/러블리/" # 스타일 입력
mall = os.listdir(path) # 쇼핑몰 리스트
for i in range(len(mall)):
  path2 = path + mall[i] + '/'
  file_list = os.listdir(path2)
  file_list_py = [file for file in file_list if file.endswith('.jpg')] # 한 쇼핑몰 폴더에 있는 이미지 파일 리스트

  for j in range(len(file_list_py)) :
    # 입력 이미지 로드
    image = Image.open(path2 + file_list_py[j])
    img_size = image.size #이미지의 크기 측정
    x = img_size[0] #넓이값
    y = img_size[1] #높이값

    if x != y:
      size = max(x, y)
      resized_img = Image.new(mode = 'RGB', size = (size, size), color = (255, 255, 255))
      offset = (round((abs(x - size)) / 2), round((abs(y - size)) / 2))
      resized_img.paste(image, offset)

      output_path = '/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭_정사각형/러블리/' + mall[i] + '/resized_' + file_list_py[j]
      resized_img.save(output_path,'png')

      print(f'{i}번째 몰인 {mall[i]}의 {j}번째 이미지가 성공적으로 저장되었습니다.')
# Out:
# 0번째 몰인 베이델리의 0번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 1번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 2번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 3번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 4번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 5번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 6번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 7번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 8번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 9번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 10번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 11번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 12번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 13번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 14번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 15번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 16번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 17번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 18번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 19번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 20번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 베이델리의 21번째 이미지가 성공적으로 저장되었습니다.
# ...

# %%
path = "/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭/럭셔리/" # 스타일 입력
mall = os.listdir(path) # 쇼핑몰 리스트
for i in range(len(mall)):
  path2 = path + mall[i] + '/'
  file_list = os.listdir(path2)
  file_list_py = [file for file in file_list if file.endswith('.jpg')] # 한 쇼핑몰 폴더에 있는 이미지 파일 리스트

  for j in range(len(file_list_py)) :
    # 입력 이미지 로드
    image = Image.open(path2 + file_list_py[j])
    img_size = image.size #이미지의 크기 측정
    x = img_size[0] #넓이값
    y = img_size[1] #높이값

    if x != y:
      size = max(x, y)
      resized_img = Image.new(mode = 'RGB', size = (size, size), color = (255, 255, 255))
      offset = (round((abs(x - size)) / 2), round((abs(y - size)) / 2))
      resized_img.paste(image, offset)

      output_path = '/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭_정사각형/럭셔리/' + mall[i] + '/resized_' + file_list_py[j]
      resized_img.save(output_path,'png')

      print(f'{i}번째 몰인 {mall[i]}의 {j}번째 이미지가 성공적으로 저장되었습니다.')
# Out:
# 0번째 몰인 세니룸의 0번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 1번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 2번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 3번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 4번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 5번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 6번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 7번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 8번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 9번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 10번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 11번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 12번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 13번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 14번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 15번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 16번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 17번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 18번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 19번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 20번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 21번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 세니룸의 22번째 이미지가 성공적으로 저장되었습니다.
# ...

# %%
path = "/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭/심플베이직/" # 스타일 입력
mall = os.listdir(path) # 쇼핑몰 리스트
for i in range(len(mall)):
  path2 = path + mall[i] + '/'
  file_list = os.listdir(path2)
  file_list_py = [file for file in file_list if file.endswith('.jpg')] # 한 쇼핑몰 폴더에 있는 이미지 파일 리스트

  for j in range(len(file_list_py)) :
    # 입력 이미지 로드
    image = Image.open(path2 + file_list_py[j])
    img_size = image.size #이미지의 크기 측정
    x = img_size[0] #넓이값
    y = img_size[1] #높이값

    if x != y:
      size = max(x, y)
      resized_img = Image.new(mode = 'RGB', size = (size, size), color = (255, 255, 255))
      offset = (round((abs(x - size)) / 2), round((abs(y - size)) / 2))
      resized_img.paste(image, offset)

      output_path = '/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭_정사각형/심플베이직/' + mall[i] + '/resized_' + file_list_py[j]
      resized_img.save(output_path,'png')

      print(f'{i}번째 몰인 {mall[i]}의 {j}번째 이미지가 성공적으로 저장되었습니다.')
# Out:
# 0번째 몰인 업타운홀릭의 0번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 1번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 2번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 3번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 4번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 5번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 6번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 7번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 8번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 9번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 10번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 11번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 12번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 13번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 14번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 15번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 16번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 17번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 18번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 업타운홀릭의 19번째 이미지가 성공적으로 저장되었습니다.
# ...

# %%
path = "/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭/섹시글램/" # 스타일 입력
mall = os.listdir(path) # 쇼핑몰 리스트
for i in range(len(mall)):
  path2 = path + mall[i] + '/'
  file_list = os.listdir(path2)
  file_list_py = [file for file in file_list if file.endswith('.jpg')] # 한 쇼핑몰 폴더에 있는 이미지 파일 리스트

  for j in range(len(file_list_py)) :
    # 입력 이미지 로드
    image = Image.open(path2 + file_list_py[j])
    img_size = image.size #이미지의 크기 측정
    x = img_size[0] #넓이값
    y = img_size[1] #높이값

    if x != y:
      size = max(x, y)
      resized_img = Image.new(mode = 'RGB', size = (size, size), color = (255, 255, 255))
      offset = (round((abs(x - size)) / 2), round((abs(y - size)) / 2))
      resized_img.paste(image, offset)

      output_path = '/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭_정사각형/섹시글램/' + mall[i] + '/resized_' + file_list_py[j]
      resized_img.save(output_path,'png')

      print(f'{i}번째 몰인 {mall[i]}의 {j}번째 이미지가 성공적으로 저장되었습니다.')
# Out:
# 0번째 몰인 모디핏의 0번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 1번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 2번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 3번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 4번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 5번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 6번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 7번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 8번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 9번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 10번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 11번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 12번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 13번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 14번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 15번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 16번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 17번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 18번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 19번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 20번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 21번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 모디핏의 22번째 이미지가 성공적으로 저장되었습니다.
# ...

# %%
path = "/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭/아메카지/" # 스타일 입력
mall = os.listdir(path) # 쇼핑몰 리스트
for i in range(len(mall)):
  path2 = path + mall[i] + '/'
  file_list = os.listdir(path2)
  file_list_py = [file for file in file_list if file.endswith('.jpg')] # 한 쇼핑몰 폴더에 있는 이미지 파일 리스트

  for j in range(len(file_list_py)) :
    # 입력 이미지 로드
    image = Image.open(path2 + file_list_py[j])
    img_size = image.size #이미지의 크기 측정
    x = img_size[0] #넓이값
    y = img_size[1] #높이값

    if x != y:
      size = max(x, y)
      resized_img = Image.new(mode = 'RGB', size = (size, size), color = (255, 255, 255))
      offset = (round((abs(x - size)) / 2), round((abs(y - size)) / 2))
      resized_img.paste(image, offset)

      output_path = '/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭_정사각형/아메카지/' + mall[i] + '/resized_' + file_list_py[j]
      resized_img.save(output_path,'png')

      print(f'{i}번째 몰인 {mall[i]}의 {j}번째 이미지가 성공적으로 저장되었습니다.')
# Out:
# 0번째 몰인 메토이소노의 0번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 1번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 2번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 3번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 4번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 5번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 6번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 7번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 8번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 9번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 10번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 11번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 12번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 13번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 14번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 15번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 16번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 17번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 18번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 19번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 메토이소노의 20번째 이미지가 성공적으로 저장되었습니다.
# ...

# %%
path = "/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭/모던시크/" # 스타일 입력
mall = os.listdir(path) # 쇼핑몰 리스트
for i in range(len(mall)):
  path2 = path + mall[i] + '/'
  file_list = os.listdir(path2)
  file_list_py = [file for file in file_list if file.endswith('.jpg')] # 한 쇼핑몰 폴더에 있는 이미지 파일 리스트

  for j in range(len(file_list_py)) :
    # 입력 이미지 로드
    image = Image.open(path2 + file_list_py[j])
    img_size = image.size #이미지의 크기 측정
    x = img_size[0] #넓이값
    y = img_size[1] #높이값

    if x != y:
      size = max(x, y)
      resized_img = Image.new(mode = 'RGB', size = (size, size), color = (255, 255, 255))
      offset = (round((abs(x - size)) / 2), round((abs(y - size)) / 2))
      resized_img.paste(image, offset)

      output_path = '/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭_정사각형/모던시크/' + mall[i] + '/resized_' + file_list_py[j]
      resized_img.save(output_path,'png')

      print(f'{i}번째 몰인 {mall[i]}의 {j}번째 이미지가 성공적으로 저장되었습니다.')
# Out:
# 0번째 몰인 에드모어의 0번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 1번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 2번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 3번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 4번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 5번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 6번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 7번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 8번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 9번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 10번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 11번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 12번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 13번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 14번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 15번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 16번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 17번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 18번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 19번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 20번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 에드모어의 21번째 이미지가 성공적으로 저장되었습니다.
# ...

# %%
path = "/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭/유니섹스/" # 스타일 입력
mall = os.listdir(path) # 쇼핑몰 리스트
for i in range(len(mall)):
  path2 = path + mall[i] + '/'
  file_list = os.listdir(path2)
  file_list_py = [file for file in file_list if file.endswith('.jpg')] # 한 쇼핑몰 폴더에 있는 이미지 파일 리스트

  for j in range(len(file_list_py)) :
    # 입력 이미지 로드
    image = Image.open(path2 + file_list_py[j])
    img_size = image.size #이미지의 크기 측정
    x = img_size[0] #넓이값
    y = img_size[1] #높이값

    if x != y:
      size = max(x, y)
      resized_img = Image.new(mode = 'RGB', size = (size, size), color = (255, 255, 255))
      offset = (round((abs(x - size)) / 2), round((abs(y - size)) / 2))
      resized_img.paste(image, offset)

      output_path = '/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭_정사각형/유니섹스/' + mall[i] + '/resized_' + file_list_py[j]
      resized_img.save(output_path,'png')

      print(f'{i}번째 몰인 {mall[i]}의 {j}번째 이미지가 성공적으로 저장되었습니다.')
# Out:
# 0번째 몰인 러브온타임의 0번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 1번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 2번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 3번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 4번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 5번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 6번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 7번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 8번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 9번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 10번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 11번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 12번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 13번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 14번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 15번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 16번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 17번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 18번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 19번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 러브온타임의 20번째 이미지가 성공적으로 저장되었습니다.
# ...

# %%
path = "/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭/클래식/" # 스타일 입력
mall = os.listdir(path) # 쇼핑몰 리스트
for i in range(len(mall)):
  path2 = path + mall[i] + '/'
  file_list = os.listdir(path2)
  file_list_py = [file for file in file_list if file.endswith('.jpg')] # 한 쇼핑몰 폴더에 있는 이미지 파일 리스트

  for j in range(len(file_list_py)) :
    # 입력 이미지 로드
    image = Image.open(path2 + file_list_py[j])
    img_size = image.size #이미지의 크기 측정
    x = img_size[0] #넓이값
    y = img_size[1] #높이값

    if x != y:
      size = max(x, y)
      resized_img = Image.new(mode = 'RGB', size = (size, size), color = (255, 255, 255))
      offset = (round((abs(x - size)) / 2), round((abs(y - size)) / 2))
      resized_img.paste(image, offset)

      output_path = '/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭_정사각형/클래식/' + mall[i] + '/resized_' + file_list_py[j]
      resized_img.save(output_path,'png')

      print(f'{i}번째 몰인 {mall[i]}의 {j}번째 이미지가 성공적으로 저장되었습니다.')
# Out:
# 0번째 몰인 애드너스의 0번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 1번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 2번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 3번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 4번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 5번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 6번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 7번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 8번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 9번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 10번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 11번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 12번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 13번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 14번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 15번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 16번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 17번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 18번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 19번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 20번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 애드너스의 21번째 이미지가 성공적으로 저장되었습니다.
# ...

# %%
path = "/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭/컨템포러리/" # 스타일 입력
mall = os.listdir(path) # 쇼핑몰 리스트
for i in range(len(mall)):
  path2 = path + mall[i] + '/'
  file_list = os.listdir(path2)
  file_list_py = [file for file in file_list if file.endswith('.jpg')] # 한 쇼핑몰 폴더에 있는 이미지 파일 리스트

  for j in range(len(file_list_py)) :
    # 입력 이미지 로드
    image = Image.open(path2 + file_list_py[j])
    img_size = image.size #이미지의 크기 측정
    x = img_size[0] #넓이값
    y = img_size[1] #높이값

    if x != y:
      size = max(x, y)
      resized_img = Image.new(mode = 'RGB', size = (size, size), color = (255, 255, 255))
      offset = (round((abs(x - size)) / 2), round((abs(y - size)) / 2))
      resized_img.paste(image, offset)

      output_path = '/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭_정사각형/컨템포러리/' + mall[i] + '/resized_' + file_list_py[j]
      resized_img.save(output_path,'png')

      print(f'{i}번째 몰인 {mall[i]}의 {j}번째 이미지가 성공적으로 저장되었습니다.')
# Out:
# 0번째 몰인 프레임퍼세컨드의 0번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 1번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 2번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 3번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 4번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 5번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 6번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 7번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 8번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 9번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 10번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 11번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 12번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 13번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 14번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 15번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 16번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 17번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 프레임퍼세컨드의 18번째 이미지가 성공적으로 저장되었습니다.
# ...

# %%
path = "/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭/빈티지/" # 스타일 입력
mall = os.listdir(path) # 쇼핑몰 리스트
for i in range(len(mall)):
  path2 = path + mall[i] + '/'
  file_list = os.listdir(path2)
  file_list_py = [file for file in file_list if file.endswith('.jpg')] # 한 쇼핑몰 폴더에 있는 이미지 파일 리스트

  for j in range(len(file_list_py)) :
    # 입력 이미지 로드
    image = Image.open(path2 + file_list_py[j])
    img_size = image.size #이미지의 크기 측정
    x = img_size[0] #넓이값
    y = img_size[1] #높이값

    if x != y:
      size = max(x, y)
      resized_img = Image.new(mode = 'RGB', size = (size, size), color = (255, 255, 255))
      offset = (round((abs(x - size)) / 2), round((abs(y - size)) / 2))
      resized_img.paste(image, offset)

      output_path = '/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭_정사각형/빈티지/' + mall[i] + '/resized_' + file_list_py[j]
      resized_img.save(output_path,'png')

      print(f'{i}번째 몰인 {mall[i]}의 {j}번째 이미지가 성공적으로 저장되었습니다.')
# Out:
# 0번째 몰인 빈블의 0번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 1번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 2번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 3번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 4번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 5번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 6번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 7번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 8번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 9번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 10번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 11번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 12번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 13번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 14번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 15번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 16번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 17번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 18번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 19번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 20번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 21번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 22번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 빈블의 23번째 이미지가 성공적으로 저장되었습니다.
# ...

# %%
path = "/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭/오피스룩/" # 스타일 입력
mall = os.listdir(path) # 쇼핑몰 리스트
for i in range(len(mall)):
  path2 = path + mall[i] + '/'
  file_list = os.listdir(path2)
  file_list_py = [file for file in file_list if file.endswith('.jpg')] # 한 쇼핑몰 폴더에 있는 이미지 파일 리스트

  for j in range(len(file_list_py)) :
    # 입력 이미지 로드
    image = Image.open(path2 + file_list_py[j])
    img_size = image.size #이미지의 크기 측정
    x = img_size[0] #넓이값
    y = img_size[1] #높이값

    if x != y:
      size = max(x, y)
      resized_img = Image.new(mode = 'RGB', size = (size, size), color = (255, 255, 255))
      offset = (round((abs(x - size)) / 2), round((abs(y - size)) / 2))
      resized_img.paste(image, offset)

      output_path = '/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭_정사각형/오피스룩/' + mall[i] + '/resized_' + file_list_py[j]
      resized_img.save(output_path,'png')

      print(f'{i}번째 몰인 {mall[i]}의 {j}번째 이미지가 성공적으로 저장되었습니다.')
# Out:
# 0번째 몰인 달리호텔의 0번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 1번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 2번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 3번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 4번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 5번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 6번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 7번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 8번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 9번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 10번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 11번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 12번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 13번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 14번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 15번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 16번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 17번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 18번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 19번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 달리호텔의 20번째 이미지가 성공적으로 저장되었습니다.
# ...

# %%
path = "/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭/캠퍼스룩/" # 스타일 입력
mall = os.listdir(path) # 쇼핑몰 리스트
for i in range(len(mall)):
  path2 = path + mall[i] + '/'
  file_list = os.listdir(path2)
  file_list_py = [file for file in file_list if file.endswith('.jpg')] # 한 쇼핑몰 폴더에 있는 이미지 파일 리스트

  for j in range(len(file_list_py)) :
    # 입력 이미지 로드
    image = Image.open(path2 + file_list_py[j])
    img_size = image.size #이미지의 크기 측정
    x = img_size[0] #넓이값
    y = img_size[1] #높이값

    if x != y:
      size = max(x, y)
      resized_img = Image.new(mode = 'RGB', size = (size, size), color = (255, 255, 255))
      offset = (round((abs(x - size)) / 2), round((abs(y - size)) / 2))
      resized_img.paste(image, offset)

      output_path = '/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭_정사각형/캠퍼스룩/' + mall[i] + '/resized_' + file_list_py[j]
      resized_img.save(output_path,'png')

      print(f'{i}번째 몰인 {mall[i]}의 {j}번째 이미지가 성공적으로 저장되었습니다.')
# Out:
# 0번째 몰인 언더비의 0번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 1번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 2번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 3번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 4번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 5번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 6번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 7번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 8번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 9번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 10번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 11번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 12번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 13번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 14번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 15번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 16번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 17번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 18번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 19번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 20번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 21번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 언더비의 22번째 이미지가 성공적으로 저장되었습니다.
# ...

# %%
path = "/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭/캐주얼/" # 스타일 입력
mall = os.listdir(path) # 쇼핑몰 리스트
for i in range(len(mall)):
  path2 = path + mall[i] + '/'
  file_list = os.listdir(path2)
  file_list_py = [file for file in file_list if file.endswith('.jpg')] # 한 쇼핑몰 폴더에 있는 이미지 파일 리스트

  for j in range(len(file_list_py)) :
    # 입력 이미지 로드
    image = Image.open(path2 + file_list_py[j])
    img_size = image.size #이미지의 크기 측정
    x = img_size[0] #넓이값
    y = img_size[1] #높이값

    if x != y:
      size = max(x, y)
      resized_img = Image.new(mode = 'RGB', size = (size, size), color = (255, 255, 255))
      offset = (round((abs(x - size)) / 2), round((abs(y - size)) / 2))
      resized_img.paste(image, offset)

      output_path = '/content/drive/MyDrive/데청캠_공유/쇼핑몰 크롭_정사각형/캐주얼/' + mall[i] + '/resized_' + file_list_py[j]
      resized_img.save(output_path,'png')

      print(f'{i}번째 몰인 {mall[i]}의 {j}번째 이미지가 성공적으로 저장되었습니다.')
# Out:
# 0번째 몰인 바잉몰의 0번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 1번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 2번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 3번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 4번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 5번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 6번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 7번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 8번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 9번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 10번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 11번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 12번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 13번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 14번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 15번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 16번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 17번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 18번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 19번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 20번째 이미지가 성공적으로 저장되었습니다.
# 0번째 몰인 바잉몰의 21번째 이미지가 성공적으로 저장되었습니다.
# ...
